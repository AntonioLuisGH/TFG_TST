# %%
pip install datasets

# %%
pip install accelerate

# %%
pip install evaluate

# %%
pip install gluonts

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# %cd /content/drive/MyDrive/TFG_Training_T/A13_extra
# !python main.py
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/TFG_Training_T/A13_extra
# /usr/local/lib/python3.10/dist-packages/gluonts/json.py:102: UserWarning: Using `json`-module for json-handling. Consider installing one of `orjson`, `ujson` to speed up serialization and deserialization.
#   warnings.warn(
# 2024-07-05 13:29:19.630498: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-05 13:29:19.630544: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-05 13:29:19.713277: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
