# %%
pip install datasets

# %%
pip install accelerate

# %%
pip install evaluate

# %%
pip install gluonts

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# %cd /content/drive/MyDrive/TFG_Training/TFG_Training_I/I23
# !python main.py
# Out:
# Mounted at /content/drive
# /content/drive/.shortcut-targets-by-id/1wBLcb8_LOg6LlhduWmV-msrphV3n7iRO/TFG_Training/TFG_Training_I/I23
# /usr/local/lib/python3.10/dist-packages/gluonts/json.py:102: UserWarning: Using `json`-module for json-handling. Consider installing one of `orjson`, `ujson` to speed up serialization and deserialization.
#   warnings.warn(
# 2024-07-11 16:32:23.616428: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-11 16:32:23.616482: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...
